# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 01 Data Exploration & Cleaning

# %%
from src import full_analyse, load_data
from src.config import RAW_DATA_PATH, PRECLEANING_STATS_PATH

# %% [markdown]
# ### 01.01 Loading Data & Analyse Data

# %%
df = load_data(RAW_DATA_PATH / "data.csv")
full_analyse(df, PRECLEANING_STATS_PATH)
# Out:
# {'descriptive_analysis':               year  selling_price      km_driven
#  count  4297.000000   4.340000e+03    4167.000000
#  mean   2013.087736   5.041273e+05   66237.198224
#  std       4.219918   5.785487e+05   46635.456187
#  min    1992.000000   2.000000e+04       1.000000
#  25%    2011.000000   2.087498e+05   35000.000000
#  50%    2014.000000   3.500000e+05   60000.000000
#  75%    2016.000000   6.000000e+05   90000.000000
#  max    2020.000000   8.900000e+06  806599.000000,
#  'na_frequency':                missing  missing_percentage
#  name                 0            0.000000
#  year                43            0.990783
#  selling_price        0            0.000000
#  km_driven          173            3.986175
#  fuel                86            1.981567
#  seller_type         65            1.497696
#  transmission         0            0.000000
#  owner               86            1.981567,
#  'corr_matrix':                    year  selling_price  km_driven
#  year           1.000000       0.413501  -0.415963
#  selling_price  0.413501       1.000000  -0.190745
#  km_driven     -0.415963      -0.190745   1.000000}
